# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import base64

# %%
#load the csv file and read in
csv_data = pd.read_csv('final_df.csv')

# Read the values of the file in the dataframe
df = pd.DataFrame(csv_data)

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(), annot = False, cmap = 'magma').set(title='Variables Correlation Heat Map')
# Out:
# [Text(0.5, 1.0, 'Variables Correlation Heat Map')]

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(), annot = True, cmap = 'magma').set(title='Variables Correlation Heat Map')
# Out:
# [Text(0.5, 1.0, 'Variables Correlation Heat Map')]

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(), annot = False, cmap = 'PiYG').set(title='Variables Correlation Heat Map')
# Out:
# [Text(0.5, 1.0, 'Variables Correlation Heat Map')]

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(), annot = True, cmap = 'PiYG').set(title='Variables Correlation Heat Map')
# Out:
# [Text(0.5, 1.0, 'Variables Correlation Heat Map')]

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(), annot = False, cmap = 'RdBu_r').set(title='Variables Correlation Heat Map')
# Out:
# [Text(0.5, 1.0, 'Variables Correlation Heat Map')]

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr()).set(title='Variables Correlation Heat Map')
#sns.diverging_palette(220, 20, as_cmap=True)
# Out:
# [Text(0.5, 1.0, 'Variables Correlation Heat Map')]

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(), annot = True, cmap = 'RdBu_r').set(title='Variables Correlation Heat Map')
# Out:
# [Text(0.5, 1.0, 'Variables Correlation Heat Map')]

# %%
#create subset of high correlation variables
subset_df = df[['social_progress_index','womens_agency', 'digital_payments', 'reliability_water_supply',
                'reliable_electricity','protection_womens_rights','physical_security_women',
                'nondiscriminatory_civil_justice','lgbt_rights','international_internet_bandwidth',
                'government_media_censorship','freedom_opinion_expression','freedom_of_belief_religion',
                'equal_treatment','bank_branches','network_coverage','acceptance_of_gays_and_lesbians',
                'freedom_of_expression','access_to_justice','media_censorship', 
                'discrimination_and_violence_against_minorities', 'perceived_criminality']]

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(subset_df.corr(), annot = True, cmap = 'RdBu_r').set(title='High Correlation with Social Progress Index')
# Out:
# [Text(0.5, 1.0, 'High Correlation with Social Progress Index')]
